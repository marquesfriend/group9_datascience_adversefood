# %%
import pandas as pd
food = pd.read_csv('/Users/tesssenftle/Downloads/adverse-food-events 2/CAERS_ASCII_2004_2017Q2.csv')
food
# Out:
#        RA_Report # RA_CAERS Created Date AEC_Event Start Date  \
# 0            65325              1/1/2004             8/4/2003
# 1            65325              1/1/2004             8/4/2003
# 2            65333              1/1/2004                  NaN
# 3            65335              1/1/2004           11/24/2003
# 4            65336              1/1/2004                  NaN
# 5            65345              1/1/2004           12/21/2003
# 6            65350              1/1/2004                  NaN
# 7            65353              1/2/2004            12/1/2003
# 8            65353              1/2/2004            12/1/2003
# 9            65354              1/2/2004                  NaN
# 10           65355              1/2/2004           10/27/2003
# 11           65356              1/2/2004           10/27/2003
# 12           65357              1/2/2004           10/27/2003
# 13           65379              1/3/2004            11/5/2003
# ...

# %%
food['PRI_FDA Industry Name'].describe()
# Out:
# count                                      90786
# unique                                        41
# top       Vit/Min/Prot/Unconv Diet(Human/Animal)
# freq                                       48501
# Name: PRI_FDA Industry Name, dtype: object

# %%
food['SYM_One Row Coded Symptoms'].describe()
# Out:
# count              90781
# unique             33546
# top       OVARIAN CANCER
# freq                4572
# Name: SYM_One Row Coded Symptoms, dtype: object

# %%
food['PRI_Reported Brand/Product Name'].describe()
# Out:
# count        90786
# unique       45685
# top       REDACTED
# freq          6081
# Name: PRI_Reported Brand/Product Name, dtype: object

# %%
brandcounts = food['PRI_Reported Brand/Product Name'].value_counts(normalize = False, sort = True, ascending = False, bins = None, dropna = True)

# %%
# %matplotlib inline
brandcounts[:20].plot(kind = 'bar', figsize = (10, 5))

# %%
food.describe()
# Out:
#          RA_Report #  PRI_FDA Industry Code  CI_Age at Adverse Event
# count   90786.000000           90786.000000             52926.000000
# mean   156577.560538              43.058082                50.755319
# std     40382.318513              16.553049                23.249385
# min     65325.000000               2.000000                 0.000000
# 25%    125985.250000              29.000000                35.000000
# 50%    168433.000000              54.000000                53.000000
# 75%    190410.750000              54.000000                68.000000
# max    214610.000000              54.000000               736.000000

# %%
food['PRI_FDA Industry Name'].describe()
# Out:
# count                                      90786
# unique                                        41
# top       Vit/Min/Prot/Unconv Diet(Human/Animal)
# freq                                       48501
# Name: PRI_FDA Industry Name, dtype: object

# %%
symptoms = food['SYM_One Row Coded Symptoms'].value_counts(normalize = False, sort = True, ascending = False, bins = None, dropna = True)

# %%
# %matplotlib inline
symptoms[:20].plot(kind = 'bar', figsize = (10, 5))

# %%
food_counts = food['PRI_FDA Industry Name'].value_counts(normalize = False, sort = True, ascending = False, bins = None, dropna = True)

# %%
# %matplotlib inline
food_counts[:20].plot(kind = 'bar', figsize = (10,5))

# %%
food.head()
# Out:
#    RA_Report # RA_CAERS Created Date AEC_Event Start Date PRI_Product Role  \
# 0        65325              1/1/2004             8/4/2003          Suspect
# 1        65325              1/1/2004             8/4/2003          Suspect
# 2        65333              1/1/2004                  NaN          Suspect
# 3        65335              1/1/2004           11/24/2003          Suspect
# 4        65336              1/1/2004                  NaN          Suspect
#
#                      PRI_Reported Brand/Product Name  PRI_FDA Industry Code  \
# 0      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS                      3
# 1      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS                      3
# 2  KROGER CLASSIC CREAM-DE-MINT CANDY MINT CHIP I...                     13
# 3                         ENFAMIL LIPIL BABY FORMULA                     40
# 4                         ENFIMIL LIPIL BABY FORMULA                     40
#
# ...

# %%
redacted = food.ix[food['PRI_Reported Brand/Product Name'] == 'REDACTED']
redacted_counts = redacted['PRI_Reported Brand/Product Name'].value_counts(normalize = False, sort = True, ascending = False, bins = None, dropna = True)
redacted_counts
# Out:
# /Users/tesssenftle/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
# REDACTED    6081
# Name: PRI_Reported Brand/Product Name, dtype: int64

# %%
food=food.ix[~(food['PRI_Product Role'] == 'Concomitant')]#removes concomitant data entries
food_counts = food['PRI_FDA Industry Name'].value_counts(normalize = False, sort = True, ascending = False, bins = None, dropna = True)
food['PRI_FDA Industry Name'].describe()
# Out:
# count                                      74558
# unique                                        41
# top       Vit/Min/Prot/Unconv Diet(Human/Animal)
# freq                                       34316
# Name: PRI_FDA Industry Name, dtype: object

# %%
# %matplotlib inline
food_counts[:20].plot(kind = 'bar', figsize = (10,5))

# %%
# %matplotlib inline
symptoms[:20].plot(kind = 'bar', figsize = (10, 5))

# %%
symptoms.describe()
# Out:
# count    33546.000000
# mean         2.706165
# std         31.038900
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max       4572.000000
# Name: SYM_One Row Coded Symptoms, dtype: float64

# %%
food=food.ix[~(food['PRI_Reported Brand/Product Name'] == 'REDACTED')]
food
# Out:
# /Users/tesssenftle/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#        RA_Report # RA_CAERS Created Date AEC_Event Start Date  \
# 0            65325              1/1/2004             8/4/2003
# 1            65325              1/1/2004             8/4/2003
# 2            65333              1/1/2004                  NaN
# 3            65335              1/1/2004           11/24/2003
# 4            65336              1/1/2004                  NaN
# 5            65345              1/1/2004           12/21/2003
# 6            65350              1/1/2004                  NaN
# 7            65353              1/2/2004            12/1/2003
# ...

# %%
oc = food.ix[food['SYM_One Row Coded Symptoms'] == 'OVARIAN CANCER']
# Out:
# /Users/tesssenftle/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
oc_counts = oc['PRI_Reported Brand/Product Name'].value_counts(normalize = False, sort = True, ascending = False, bins = None, dropna = True)
oc_counts
# Out:
# SHOWER TO SHOWER TALCUM POWDER                                              30
# JOHNSON'S BABY POWDER                                                       22
# JOHNSON'S POWDER                                                            15
# SHOWER TO SHOWER POWDER                                                     15
# SHOWER TO SHOWER TALCUM PRODUCT                                             13
# JOHNSONS BABY POWDER                                                         4
# JOHNSONS POWDER                                                              3
# SHOWER TO SHOWER TALCUM                                                      2
# JOHNSON AND JOHNSON BABY POWDER(TALC)                                        2
# SHOWER TO SHOWER POWDER(POWDER)                                              2
# SHOWER TO SHOWER POWDER (POWDER)                                             2
# PURITANS PRIDE CLA 1000 MG RAPID RELEASE SOFTGELS                            1
# ...

# %%
# %matplotlib inline
oc_counts[:20].plot(kind = 'bar', figsize = (10, 5))

# %%
# %matplotlib inline
oc_counts[:20].plot(kind = 'bar', figsize = (10, 5))
